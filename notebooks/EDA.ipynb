# %%
from src.ingestion.load_data import DataLoader
from src.ingestion.validate_data import DataValidator

# %%
loader = DataLoader()

df = loader.load_data(1000)

validator = DataValidator()

validator.validate(df)
# Out:
# Duplicate IDs : 0
# id            0
# title         0
# abstract      0
# authors       0
# categories    0
# dtype: int64

# %%
df.head()
# Out:
#          id           submitter  \
# 0  704.0001      Pavel Nadolsky
# 1  704.0002        Louis Theran
# 2  704.0003         Hongjun Pan
# 3  704.0004        David Callan
# 4  704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1000 non-null   float64
#  1   submitter       1000 non-null   str
#  2   authors         1000 non-null   str
#  3   title           1000 non-null   str
#  4   comments        901 non-null    str
#  5   journal-ref     573 non-null    str
#  6   doi             663 non-null    str
#  7   report-no       78 non-null     str
#  8   categories      1000 non-null   str
#  9   license         61 non-null     str
#  10  abstract        1000 non-null   str
#  11  versions        1000 non-null   object
#  12  update_date     1000 non-null   str
#  13  authors_parsed  1000 non-null   object
# dtypes: float64(1), object(2), str(11)
# memory usage: 1.1+ MB

# %%
df.describe(include="all")
# Out:
#                  id    submitter    authors  \
# count   1000.000000         1000       1000
# unique          NaN          921        965
# top             NaN  Igor Grabec  I. Grabec
# freq            NaN            7          4
# mean     704.050050          NaN        NaN
# std        0.028882          NaN        NaN
# min      704.000100          NaN        NaN
# 25%      704.025075          NaN        NaN
# 50%      704.050050          NaN        NaN
# 75%      704.075025          NaN        NaN
# max      704.100000          NaN        NaN
#
#                                                     title            comments  \
# count                                                1000                 901
# unique                                               1000                 816
# top     Calculation of prompt diphoton production cros...  4 pages, 4 figures
# freq                                                    1                   9
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# submitter           0
# authors             0
# title               0
# comments           99
# journal-ref       427
# doi               337
# report-no         922
# categories          0
# license           939
# abstract            0
# versions            0
# update_date         0
# authors_parsed      0
# dtype: int64

# %%
df["categories"].value_counts().head(20)
# Out:
# categories
# astro-ph                             179
# quant-ph                              42
# hep-th                                40
# hep-ph                                37
# cond-mat.mes-hall                     29
# cond-mat.str-el                       27
# cond-mat.mtrl-sci                     25
# gr-qc                                 24
# nucl-th                               16
# nucl-ex                               13
# math.CO                               12
# physics.gen-ph                        11
# hep-ex                                11
# math.PR                               10
# physics.optics                        10
# cs.IT math.IT                         10
# cond-mat.other                        10
# cond-mat.supr-con                      9
# math.NT                                8
# cond-mat.supr-con cond-mat.str-el      8
# Name: count, dtype: int64

# %%
df["abstract_length"] = df["abstract"].str.len()

df["abstract_length"].describe()
# Out:
# count    1000.000000
# mean      799.138000
# std       401.299786
# min        44.000000
# 25%       507.750000
# 50%       731.500000
# 75%      1035.250000
# max      1869.000000
# Name: abstract_length, dtype: float64
