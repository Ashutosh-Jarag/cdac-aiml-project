# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
# Out:
# c:\Users\DELL\Desktop\Cdac\aiml-project

# %%
from src.llm.gemini_client import ask_gemini

response = ask_gemini(
    "Explain what a transformer model is in 3 lines."
)

print(response)
# Out:
# A transformer is a neural network architecture designed to process sequential data, like text, by modeling relationships between all parts of the input. It uses a mechanism called "self-attention" to weigh the importance of different words relative to each other, irrespective of their distance. This allows for highly parallel processing and effective capture of long-range dependencies, powering advanced AI for tasks like translation and generation.

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\DELL\Desktop\Cdac\aiml-project\notebooks

# %%
import sys

for p in sys.path:
    print(p)
# Out:
# c:\Users\DELL\Desktop\Cdac\aiml-project
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\python313.zip
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\DLLs
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0
# c:\Users\DELL\Desktop\Cdac\aiml-project\myenv
#
# c:\Users\DELL\Desktop\Cdac\aiml-project\myenv\Lib\site-packages

# %%
import os

print(os.path.exists("../src/llm/gemini_client.py"))
# Out:
# True

# %%
import os
import sys

print(os.getcwd())
print(os.path.exists("../src/llm/gemini_client.py"))
print(sys.path)
# Out:
# c:\Users\DELL\Desktop\Cdac\aiml-project\notebooks
# True
# ['c:\\Users\\DELL\\Desktop\\Cdac\\aiml-project', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\\python313.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0', 'c:\\Users\\DELL\\Desktop\\Cdac\\aiml-project\\myenv', '', 'c:\\Users\\DELL\\Desktop\\Cdac\\aiml-project\\myenv\\Lib\\site-packages']

# %%
import src.llm.gemini_client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import src.llm.gemini_client
#
# ModuleNotFoundError: No module named 'src.llm.gemini_client'

# %%
import os

print(os.listdir("../src/llm"))
# Out:
# ['gemini_client.py', '__init__.py', '__pycache__']

# %%
from pathlib import Path

for f in Path("../src/llm").iterdir():
    print(f.name)
# Out:
# gemini_client.py
# __init__.py
# __pycache__

# %%
from pathlib import Path

print(Path("../src/__init__.py").exists())
print(Path("../src/llm/__init__.py").exists())
# Out:
# True
# True

# %%
import pkgutil
import src

print(list(pkgutil.iter_modules(src.__path__)))
# Out:
# []

# %%
import pkgutil
import src

print([m.name for m in pkgutil.iter_modules(src.__path__)])
# Out:
# []

# %%
import src
print(src)
print(src.__file__)
# Out:
# <module 'src' from 'c:\\Users\\DELL\\Desktop\\Cdac\\aiml-project\\notebooks\\src\\__init__.py'>
# c:\Users\DELL\Desktop\Cdac\aiml-project\notebooks\src\__init__.py

# %%
import pkgutil
import src

print([m.name for m in pkgutil.iter_modules(src.__path__)])
# Out:
# []

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\DELL\Desktop\Cdac\aiml-project\myenv\Scripts\python.exe

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import src

print(src.__file__)
# Out:
# c:\Users\DELL\Desktop\Cdac\aiml-project\src\__init__.py

# %%
from src.llm.gemini_client import ask_gemini

# %%
from src.vectorstore.chroma_client import retrieve_papers

results = retrieve_papers(
    "Black Holes"
)

print(results.keys())
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.vectorstore.chroma_client import retrieve_papers
#       2
#       3 results = retrieve_papers(
#       4     "Black Holes"
#
# File c:\Users\DELL\Desktop\Cdac\aiml-project\src\vectorstore\chroma_client.py:12
#       7 # Connect to ChromaDB
#       8 client = chromadb.PersistentClient(
#       9     path="data/embeddings"
#      10 )
# ---> 12 collection = client.get_collection(
#      13     "research_papers"
#      14 )
#      17 def retrieve_papers(
#      18     query: str,
#      19     top_k: int = 5
#      20 ):
#      21     """
#      22     Retrieve the most relevant research papers.
#      23     """
#
# ...

# %%
for paper in results["metadatas"][0]:

    print(paper["title"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for paper in results["metadatas"][0]:
#       2
#       3     print(paper["title"])
#
# NameError: name 'results' is not defined

# %%
from pathlib import Path

print("Chroma DB folder:")
print((Path("../chroma_db")).resolve())

print()

print("Embeddings folder:")
print((Path("../data/embeddings")).resolve())
# Out:
# Chroma DB folder:
# C:\Users\DELL\Desktop\Cdac\aiml-project\chroma_db
#
# Embeddings folder:
# C:\Users\DELL\Desktop\Cdac\aiml-project\data\embeddings

# %%
from src.vectorstore.chroma_client import retrieve_papers

results = retrieve_papers(
    "Black Holes"
)

print(results.keys())
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# dict_keys(['ids', 'embeddings', 'documents', 'uris', 'included', 'data', 'metadatas', 'distances'])

# %%
for paper in results["metadatas"][0]:

    print(paper["title"])
# Out:
# Topology Change of Black Holes
# The First Law for Boosted Kaluza-Klein Black Holes
# Hawking radiation of linear dilaton black holes
# General Relativity Today
# Binary Systems as Test-beds of Gravity Theories

# %%
import chromadb

client = chromadb.PersistentClient(path="../data/embeddings")

print(client.list_collections())
# Out:
# []

# %%
import chromadb

client = chromadb.PersistentClient(path="../chroma_db")
print(client.list_collections())
# Out:
# [Collection(name=research_papers)]

# %%
import chromadb

client = chromadb.PersistentClient(path="../data/embeddings")
print(client.list_collections())
# Out:
# []

# %%
from src.rag.rag_pipeline import ask_question

# %%
response = ask_question(
    "Explain Hawking radiation."
)

print(response)
# Out:
# Hawking radiation refers to a semi-classical radiation spectrum. For a class of non-asymptotically flat charged dilaton black holes, known as linear dilaton black holes, this radiation spectrum has been computed exactly. In the high-frequency regime, the temperature associated with this radiation generally matches the surface gravity result. However, massless black holes, even with a finite surface gravity, are shown not to radiate ("Hawking radiation of linear dilaton black holes").
#
# The concept of Gibbons-Hawking radiation (a related phenomenon) has been proposed to be simulated using a single trapped ion with an exponentially decaying trap frequency. While an initial proposal used an incorrect Hamiltonian, the corrected result for a single ion, though different from the actual Gibbons-Hawking spectrum, still shares an important experimental signature ("A Single Trapped Ion as a Time-Dependent Harmonic Oscillator").

# %%
ask_question("What is Quantum Computing?")
# Out:
# "I couldn't find enough information in the retrieved papers."

# %%
ask_question("Explain Black Holes.")
# Out:
# "I couldn't find enough information in the retrieved papers."

# %%
from src.rag.manual_langchain_rag import ask_llm

print(
    ask_llm(
        "Explain transformers in 3 lines."
    )
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 1.  A powerful neural network architecture for processing sequential data like text.
# 2.  It uses self-attention to understand relationships between all parts of an input sequence simultaneously.
# 3.  This enables efficient parallel processing, captures long-range context, and powers modern Large Language Models (LLMs).

# %%
import src.rag.langchain_rag as rag

# %%
import src.rag.langchain_rag as rag

print(dir(rag))
# Out:
# ['ChatGoogleGenerativeAI', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'ask_llm', 'llm', 'load_dotenv', 'os']

# %%
from src.rag.langchain_rag import ask_question

# %%
import importlib
import src.rag.langchain_rag as rag

importlib.reload(rag)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# <module 'src.rag.langchain_rag' from 'c:\\Users\\DELL\\Desktop\\Cdac\\aiml-project\\src\\rag\\langchain_rag.py'>

# %%
print(dir(rag))
# Out:
# ['ChatGoogleGenerativeAI', 'ChatPromptTemplate', 'StrOutputParser', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'ask_llm', 'ask_question', 'build_context', 'llm', 'load_dotenv', 'os', 'parser', 'prompt', 'retrieve_papers']

# %%
from src.rag.langchain_rag import ask_question

print(
    ask_question(
        "Explain Transformers in 2 lines"
    )
)
# Out:
# I couldn't find enough information in the retrieved papers.

# %%
from src.vectorstore.chroma_client import retrieve_papers
from src.rag.langchain_rag import build_context

results = retrieve_papers("Explain Hawking Radiation")

context = build_context(results)

print(context)
# Out:
# Paper 1
#
# Title:
# Hawking radiation of linear dilaton black holes
#
# Authors:
# G. Clement, J.C. Fabris and G.T. Marques
#
# Category:
# gr-qc
#
# Abstract:
# Hawking radiation of linear dilaton black holes   We compute exactly the semi-classical radiation spectrum for a class of
# non-asymptotically flat charged dilaton black holes, the so-called linear
# dilaton black holes. In the high frequency regime, the temperature for these
# black holes generically agrees with the surface gravity result. In the special
# case where the black hole is massless, we show that, although the surface
# gravity remains finite, there is no radiation, in agreement with the fact that
# massless objects cannot radiate.
#
#
#
#
# Paper 2
#
# Title:
# A Single Trapped Ion as a Time-Dependent Harmonic Oscillator
#
# Authors:
# Nicolas C. Menicucci and G. J. Milburn
#
# Category:
# quant-ph
#
# Abstract:
# ...

# %%
from src.vectorstore.langchain_vectorstore import retriever

docs = retriever.invoke("Black Holes")

print(len(docs))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# 0

# %%
docs[0].page_content[:500]

# %%
from pathlib import Path

from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

DB_PATH = Path("../data/embeddings").resolve()

print(DB_PATH)
# Out:
# C:\Users\DELL\Desktop\Cdac\aiml-project\data\embeddings

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma(
    persist_directory=str(DB_PATH),
    collection_name="research_papers",
    embedding_function=embeddings
)

retriever = vectorstore.as_retriever()

docs = retriever.invoke("Black Holes")

print(len(docs))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# 0

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma(
    persist_directory="../data/embeddings",
    collection_name="research_papers",
    embedding_function=embeddings,
)

print(vectorstore._collection.count())
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# 0
